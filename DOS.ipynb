# %% [markdown]
# ## Calculate Days of Sale at Plant Material Combination.
#
# Author: Syamanthaka B
#
# Created: May 2019
#
# ----------------------------------------------------------------------------------------------------------
#
# * Input 1 is inventory master data with plant, material and closing stock.
# * Input 2 is price per unit for a plant material combination
#
# The code below wrangles these data sets to get a 3 month forward looking Days of Sale or DOS.
# DOS is calculated as total cost of inventory / number of days.
#
# Total cost of inventory is taken over forward looking 3 months, eg. for the month of Jan, forward looking 3 months would include Feb, Mar and Apr. Similar approach is taken for number of days.
#
# Note: Currently the calculating the total cost over upcoming 3 months takes a bit of computing time. WIP on time optimizations
#
# #### Necessary imports

# %%
import pandas as pd
from datetime import datetime as dt
import time
import numpy as np

# %% [markdown]
# #### Open input 1 and clean up

# %%
inventory_raw = pd.read_excel("INV_BEST - Backup.xlsx", sheet_name="Sheet1")
inventory_raw.rename(columns=lambda x: x.strip(), inplace=True)
inventory_raw = inventory_raw[['Plnt', 'Material', 'From Date', 'Opening Stock', 'Total Receipt Qties', 
                               'Total Issue Quantities', 'Closing Stock']]
inventory_raw = inventory_raw[~inventory_raw['Plnt'].isnull()] ## Some extra cleaning found coincidentally
inventory_raw.dropna()
inventory_raw['Material'] = inventory_raw['Material'].str.strip()
inventory_raw.head()
# Out:
#    Plnt      Material  From Date  Opening Stock  Total Receipt Qties  \
# 0  NL92  032210700233 2018-08-01         27.000                  8.0
# 1  NL92  062236202002 2018-08-01         91.000                 17.0
# 2  NL92    0722237002 2018-08-01          0.000                  2.0
# 3  NL92  082201115003 2018-08-01        127.440                  0.0
# 4  NL92  082201165013 2018-08-01        148.675                  0.0
#
#    Total Issue Quantities  Closing Stock
# 0                   -5.00         30.000
# 1                  -12.00         96.000
# 2                   -2.00          0.000
# 3                   -0.10        127.340
# 4                   -0.08        148.595

# %% [markdown]
# #### Add new column for month

# %%
inventory_raw['Month'] = pd.DatetimeIndex(inventory_raw['From Date']).month
inventory_raw.head()
# Out:
#    Plnt      Material  From Date  Opening Stock  Total Receipt Qties  \
# 0  NL92  032210700233 2018-08-01         27.000                  8.0
# 1  NL92  062236202002 2018-08-01         91.000                 17.0
# 2  NL92    0722237002 2018-08-01          0.000                  2.0
# 3  NL92  082201115003 2018-08-01        127.440                  0.0
# 4  NL92  082201165013 2018-08-01        148.675                  0.0
#
#    Total Issue Quantities  Closing Stock  Month
# 0                   -5.00         30.000      8
# 1                  -12.00         96.000      8
# 2                   -2.00          0.000      8
# 3                   -0.10        127.340      8
# 4                   -0.08        148.595      8

# %%
## Some cosmetic edits
for i in range(3,7):
    inventory_raw.iloc[:,i] = inventory_raw.iloc[:,i].apply(lambda x: round(x))
inventory_raw.head()
# Out:
#    Plnt      Material  From Date  Opening Stock  Total Receipt Qties  \
# 0  NL92  032210700233 2018-08-01             27                    8
# 1  NL92  062236202002 2018-08-01             91                   17
# 2  NL92    0722237002 2018-08-01              0                    2
# 3  NL92  082201115003 2018-08-01            127                    0
# 4  NL92  082201165013 2018-08-01            149                    0
#
#    Total Issue Quantities  Closing Stock  Month
# 0                      -5             30      8
# 1                     -12             96      8
# 2                      -2              0      8
# 3                       0            127      8
# 4                       0            149      8

# %% [markdown]
# #### Open input 2 and process

# %%
std_price_raw = pd.read_excel("STD_PRICE.xlsx", sheet_name="Sheet1")
std_price_raw.rename(columns=lambda x: x.strip(), inplace=True)
std_price_raw.head()
# Out:
#    Plnt        Material                      Material Description  \
# 0  NL92  0322-107-00233  WIRE BRAID 14AWG CU/SN
# 1  NL92  0622-362-02002  SOLDERWIRE 97SC 309 5C 1.2mm 0.5kg
# 2  NL92    0722-237-002  2LG B-CAB. FD12 MID
# 3  NL92  0822-011-15003  HEAT SHRINK, POLYOLEFIN, 1/8", BK
# 4  NL92  0822-011-65013  SH-SLEEVE RNF-3000-12/4-X-SP
#
#                    KEY Mat_Type  MRPpr  ProcType  STD_PRICE
# 0  0322-107-00233:NL92     HAWA  BHWA   F              6.24
# 1  0622-362-02002:NL92     FERT  BHWA   F             75.32
# 2    0722-237-002:NL92     ZMAT  BZMT   E         999999.00
# 3  0822-011-15003:NL92     HAWA  BHWA   F              4.21
# 4  0822-011-65013:NL92     HAWA  PMC1   F              3.92

# %%
## Clean up
std_price_raw['Material'] = std_price_raw['Material'].str.replace('-', '')
std_price_raw.head()
# Out:
#    Plnt      Material                      Material Description  \
# 0  NL92  032210700233  WIRE BRAID 14AWG CU/SN
# 1  NL92  062236202002  SOLDERWIRE 97SC 309 5C 1.2mm 0.5kg
# 2  NL92    0722237002  2LG B-CAB. FD12 MID
# 3  NL92  082201115003  HEAT SHRINK, POLYOLEFIN, 1/8", BK
# 4  NL92  082201165013  SH-SLEEVE RNF-3000-12/4-X-SP
#
#                    KEY Mat_Type  MRPpr  ProcType  STD_PRICE
# 0  0322-107-00233:NL92     HAWA  BHWA   F              6.24
# 1  0622-362-02002:NL92     FERT  BHWA   F             75.32
# 2    0722-237-002:NL92     ZMAT  BZMT   E         999999.00
# 3  0822-011-15003:NL92     HAWA  BHWA   F              4.21
# 4  0822-011-65013:NL92     HAWA  PMC1   F              3.92

# %%
## Selecting required columns
std_price_raw = std_price_raw.drop_duplicates()
std_price_tmp = std_price_raw[['Plnt', 'Material', 'STD_PRICE']]
std_price_tmp.head()
# Out:
#    Plnt      Material  STD_PRICE
# 0  NL92  032210700233       6.24
# 1  NL92  062236202002      75.32
# 2  NL92    0722237002  999999.00
# 3  NL92  082201115003       4.21
# 4  NL92  082201165013       3.92

# %% [markdown]
# #### Merge the two inputs

# %%
inventory_df = pd.merge(inventory_raw, std_price_tmp, how="left", on=['Plnt', 'Material'])
inventory_df.head()
# Out:
#    Plnt      Material  From Date  Opening Stock  Total Receipt Qties  \
# 0  NL92  032210700233 2018-08-01             27                    8
# 1  NL92  062236202002 2018-08-01             91                   17
# 2  NL92    0722237002 2018-08-01              0                    2
# 3  NL92  082201115003 2018-08-01            127                    0
# 4  NL92  082201165013 2018-08-01            149                    0
#
#    Total Issue Quantities  Closing Stock  Month  STD_PRICE
# 0                      -5             30      8       6.24
# 1                     -12             96      8      75.32
# 2                      -2              0      8  999999.00
# 3                       0            127      8       4.21
# 4                       0            149      8       3.92

# %% [markdown]
# #### Calculate total cost of closing stock

# %%
inventory_df['Total_cost'] = inventory_df['Closing Stock'] * inventory_df['STD_PRICE']
inventory_df.head()
# Out:
#    Plnt      Material  From Date  Opening Stock  Total Receipt Qties  \
# 0  NL92  032210700233 2018-08-01             27                    8
# 1  NL92  062236202002 2018-08-01             91                   17
# 2  NL92    0722237002 2018-08-01              0                    2
# 3  NL92  082201115003 2018-08-01            127                    0
# 4  NL92  082201165013 2018-08-01            149                    0
#
#    Total Issue Quantities  Closing Stock  Month  STD_PRICE  Total_cost
# 0                      -5             30      8       6.24      187.20
# 1                     -12             96      8      75.32     7230.72
# 2                      -2              0      8  999999.00        0.00
# 3                       0            127      8       4.21      534.67
# 4                       0            149      8       3.92      584.08

# %% [markdown]
# #### Aggregate for plant material and month

# %%
inventory_pm = inventory_df.groupby(['Plnt', 'Material', 'Month'])['Total_cost'].agg('sum').reset_index()
inventory_pm.head()
# Out:
#    Plnt      Material  Month  Total_cost
# 0  NL92  012204310004      5        0.00
# 1  NL92  012204310004      7      738.40
# 2  NL92  032210700233      3      199.68
# 3  NL92  032210700233      4      193.44
# 4  NL92  032210700233      5      199.68

# %%
print(inventory_pm.shape)
# Out:
# (68119, 4)

# %%
temp = inventory_pm.iloc[:100]
temp['Agg_sum'] = ''
#temp
# Out:
# C:\Users\320054667\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# #### Function for forward looking cost of consumption.
# Needs performance optimization

# %%
##TODO needs further optimiation
def calc_3magg(row):
    month_no = row['Month']
    plant = row['Plnt']
    mat = row['Material']
    
    np3 = [month_no + 1, month_no + 2, month_no + 3]

    m3sum = inventory_pm.loc[(inventory_pm['Plnt'] == plant) & (inventory_pm['Material'] == mat) & (inventory_pm['Month'].isin(np3))]['Total_cost'].agg('sum')
   
    return (m3sum)
    
start = time.time()
#temp['Agg_sum'] = temp.apply(calc_3magg, axis=1)
inventory_pm['Agg_sum'] = inventory_pm.apply(calc_3magg, axis=1)
end = time.time()
print(end - start)
inventory_pm.head()
#temp.head()
# Out:
# 902.8549842834473
#    Plnt      Material  Month  Total_cost  Agg_sum
# 0  NL92  012204310004      5        0.00   738.40
# 1  NL92  012204310004      7      738.40     0.00
# 2  NL92  032210700233      3      199.68   580.32
# 3  NL92  032210700233      4      193.44   555.36
# 4  NL92  032210700233      5      199.68   542.88

# %% [markdown]
# #### Creating a month to no. of days reference df

# %%
month_data = [[1,31], [2,28], [3,31], [4,30], [5,31], [6,30], [7,31], [8,31], [9,30], [10,31], [11,30], [12,31]]
month_day_df = pd.DataFrame(month_data, columns = ['Month', 'NDays'])
month_day_df.head()
# Out:
#    Month  NDays
# 0      1     31
# 1      2     28
# 2      3     31
# 3      4     30
# 4      5     31

# %%
for idx, row in month_day_df.iterrows():
    np3m = [row.Month + 1, row.Month + 2, row.Month + 3]
    n3days = month_day_df.loc[month_day_df['Month'].isin(np3m)]['NDays'].agg('sum')
    month_day_df.loc[idx,'N3days'] = n3days

lq = [10,11,12]
lastq = month_day_df['Month'].isin(lq)
month_day_df['N3days'][lastq] = 0
month_day_df
# Out:
#     Month  NDays  N3days
# 0       1     31      89
# 1       2     28      92
# 2       3     31      91
# 3       4     30      92
# 4       5     31      92
# 5       6     30      92
# 6       7     31      92
# 7       8     31      91
# 8       9     30      92
# 9      10     31       0
# 10     11     30       0
# 11     12     31       0

# %% [markdown]
# #### Adding the month and no. of days forward looking to the inventory df

# %%
inventory_pm = pd.merge(inventory_pm, month_day_df, how="left", on=['Month'])
inventory_pm.head()
# Out:
#    Plnt      Material  Month  Total_cost  Agg_sum  NDays  N3days
# 0  NL92  012204310004      5        0.00   738.40     31      92
# 1  NL92  012204310004      7      738.40     0.00     31      92
# 2  NL92  032210700233      3      199.68   580.32     31      91
# 3  NL92  032210700233      4      193.44   555.36     30      92
# 4  NL92  032210700233      5      199.68   542.88     31      92

# %% [markdown]
# #### Calculating DOS

# %%
inventory_pm['DOS'] = inventory_pm['Agg_sum']/inventory_pm['N3days']
inventory_pm.head()
# Out:
#    Plnt      Material  Month  Total_cost  Agg_sum  NDays  N3days       DOS
# 0  NL92  012204310004      5        0.00   738.40     31      92  8.026087
# 1  NL92  012204310004      7      738.40     0.00     31      92  0.000000
# 2  NL92  032210700233      3      199.68   580.32     31      91  6.377143
# 3  NL92  032210700233      4      193.44   555.36     30      92  6.036522
# 4  NL92  032210700233      5      199.68   542.88     31      92  5.900870

# %% [markdown]
# #### Final cleaning

# %%
inventory_pm['DOS'].replace([np.inf], 100000000, inplace=True)
inventory_pm['DOS'].replace([np.nan], 0, inplace=True)
inventory_pm[inventory_pm['N3days'] == 0]
# Out:
#        Plnt      Material  Month  Total_cost   Agg_sum  NDays  N3days  \
# 9      NL92  032210700233     10      243.36    436.80     31       0
# 10     NL92  032210700233     11      224.64    212.16     30       0
# 11     NL92  032210700233     12      212.16      0.00     31       0
# 19     NL92  062236202002     10     5799.64  12955.04     31       0
# 20     NL92  062236202002     11     6703.48   6251.56     30       0
# 21     NL92  062236202002     12     6251.56      0.00     31       0
# 23     NL92    0781439102     11        0.00      0.00     30       0
# 28     NL92  082201115003     10      534.67    534.67     31       0
# 29     NL92  082201115003     11      534.67      0.00     30       0
# 40     NL92  082201180008     11      302.00    302.00     30       0
# 41     NL92  082201180008     12      302.00      0.00     31       0
# 49     NL92  082209130034     10     3559.35   7027.20     31       0
# 50     NL92  082209130034     11     3528.85   3498.35     30       0
# 51     NL92  082209130034     12     3498.35      0.00     31       0
# 59     NL92  122200198318     10       34.92     52.38     31       0
# 60     NL92  122200198318     11       34.92     17.46     30       0
# 61     NL92  122200198318     12       17.46      0.00     31       0
# 67     NL92  122200198319     10     4155.48      0.00     31       0
# 73     NL92  122210098209     10      317.60      0.00     31       0
# 81     NL92  122210098812     10      513.63    692.64     31       0
# 82     NL92  122210098812     11      384.93    307.71     30       0
# 83     NL92  122210098812     12      307.71      0.00     31       0
# 91     NL92  122210198188     10     1053.70   1488.30     31       0
# 92     NL92  122210198188     11      787.20    701.10     30       0
# 93     NL92  122210198188     12      701.10      0.00     31       0
# 101    NL92  122210400013     10      122.40   1186.20     31       0
# 102    NL92  122210400013     11       48.60   1137.60     30       0
# 103    NL92  122210400013     12     1137.60      0.00     31       0
# 105    NL92  122210425002     11      532.80      0.00     30       0
# 113    NL92  122210498147     10     1530.88    965.12     31       0
# ...     ...           ...    ...         ...       ...    ...     ...
# 67996  NL9G  989601073171     11      432.14      0.00     30       0
# 67997  NL9G  989601073171     12        0.00      0.00     31       0
# 67998  NL9G  989601073181     11     1050.75      0.00     30       0
# 67999  NL9G  989601073181     12        0.00      0.00     31       0
# 68009  NL9G  989601080421     10    23480.00      0.00     31       0
# 68010  NL9G  989601080421     11        0.00      0.00     30       0
# 68011  NL9G  989601080421     12        0.00      0.00     31       0
# 68017  NL9G  989601080511     10        0.00      0.00     31       0
# 68018  NL9G  989601080511     12        0.00      0.00     31       0
# 68026  NL9G  989601080601     10        0.00      0.00     31       0
# 68027  NL9G  989601080601     11        0.00      0.00     30       0
# 68028  NL9G  989601080601     12        0.00      0.00     31       0
# 68035  NL9G  989601080961     11        0.00      0.00     30       0
# 68036  NL9G  989601080961     12        0.00      0.00     31       0
# 68066  NL9G  989601081101     11        0.00      0.00     30       0
# 68067  NL9G  989601081101     12        0.00      0.00     31       0
# 68073  NL9G  989601081111     11        0.00      0.00     30       0
# 68074  NL9G  989601081111     12        0.00      0.00     31       0
# 68098  NL9G  989601081271     10        0.00      0.00     31       0
# 68099  NL9G  989601081281     10        0.00      0.00     31       0
# 68100  NL9G  989601081291     12        0.00      0.00     31       0
# 68101  NL9G  989601081321     12     5975.00      0.00     31       0
# 68102  NL9G  989601081331     11        0.00      0.00     30       0
# 68103  NL9G  989601081341     12        0.00      0.00     31       0
# 68106  NL9G  989601082000     10        0.00      0.00     31       0
# 68107  NL9G  989601082000     11        0.00      0.00     30       0
# 68108  NL9G  989601082000     12        0.00      0.00     31       0
# 68116  NL9I  RTRPN9IVENDR     10        0.00      0.00     31       0
# 68117  NL9I  RTRPN9IVENDR     11        0.00      0.00     30       0
# 68118  NL9I  RTRPN9IVENDR     12        0.00      0.00     31       0
#
#                DOS
# 9      100000000.0
# 10     100000000.0
# 11             0.0
# 19     100000000.0
# 20     100000000.0
# 21             0.0
# 23             0.0
# 28     100000000.0
# 29             0.0
# 40     100000000.0
# 41             0.0
# 49     100000000.0
# 50     100000000.0
# 51             0.0
# 59     100000000.0
# 60     100000000.0
# 61             0.0
# 67             0.0
# 73             0.0
# 81     100000000.0
# 82     100000000.0
# 83             0.0
# 91     100000000.0
# 92     100000000.0
# 93             0.0
# 101    100000000.0
# 102    100000000.0
# 103            0.0
# 105            0.0
# 113    100000000.0
# ...            ...
# 67996          0.0
# 67997          0.0
# 67998          0.0
# 67999          0.0
# 68009          0.0
# 68010          0.0
# 68011          0.0
# 68017          0.0
# 68018          0.0
# 68026          0.0
# 68027          0.0
# 68028          0.0
# 68035          0.0
# 68036          0.0
# 68066          0.0
# 68067          0.0
# 68073          0.0
# 68074          0.0
# 68098          0.0
# 68099          0.0
# 68100          0.0
# 68101          0.0
# 68102          0.0
# 68103          0.0
# 68106          0.0
# 68107          0.0
# 68108          0.0
# 68116          0.0
# 68117          0.0
# 68118          0.0
#
# [21218 rows x 8 columns]

# %%
inventory_pm['DOS'] = inventory_pm['DOS'].apply(lambda x: round(x))

# %%
inventory_pm.rename(columns={'Agg_sum':'ADC'}, inplace=True)
inventory_pm.head()
# Out:
#    Plnt      Material  Month  Total_cost     ADC  NDays  N3days  DOS
# 0  NL92  012204310004      5        0.00  738.40     31      92    8
# 1  NL92  012204310004      7      738.40    0.00     31      92    0
# 2  NL92  032210700233      3      199.68  580.32     31      91    6
# 3  NL92  032210700233      4      193.44  555.36     30      92    6
# 4  NL92  032210700233      5      199.68  542.88     31      92    6

# %% [markdown]
# #### Add a flag to see if there is demand or not

# %%
inventory_pm['Demand_flag'] = np.where(inventory_pm['ADC'] == 0, 'X', '')
inventory_pm.head()
# Out:
#    Plnt      Material  Month  Total_cost     ADC  NDays  N3days  DOS  \
# 0  NL92  012204310004      5        0.00  738.40     31      92    8
# 1  NL92  012204310004      7      738.40    0.00     31      92    0
# 2  NL92  032210700233      3      199.68  580.32     31      91    6
# 3  NL92  032210700233      4      193.44  555.36     30      92    6
# 4  NL92  032210700233      5      199.68  542.88     31      92    6
#
#   Demand_flag
# 0
# 1           X
# 2
# 3
# 4

# %%
std_price_raw = std_price_raw.drop_duplicates()
std_price_raw = std_price_raw[['Plnt', 'Material', 'Material Description', 'Mat_Type', 'MRPpr', 'ProcType']]
std_price_raw.head()
# Out:
#    Plnt      Material                      Material Description Mat_Type  \
# 0  NL92  032210700233  WIRE BRAID 14AWG CU/SN                       HAWA
# 1  NL92  062236202002  SOLDERWIRE 97SC 309 5C 1.2mm 0.5kg           FERT
# 2  NL92    0722237002  2LG B-CAB. FD12 MID                          ZMAT
# 3  NL92  082201115003  HEAT SHRINK, POLYOLEFIN, 1/8", BK            HAWA
# 4  NL92  082201165013  SH-SLEEVE RNF-3000-12/4-X-SP                 HAWA
#
#    MRPpr  ProcType
# 0  BHWA   F
# 1  BHWA   F
# 2  BZMT   E
# 3  BHWA   F
# 4  PMC1   F

# %%
print(inventory_pm.shape)
# Out:
# (68119, 9)

# %%
inventory_pm = pd.merge(inventory_pm, std_price_raw, how="left", on=['Plnt', 'Material'])
print(inventory_pm.shape)
inventory_pm.head()
# Out:
# (68681, 13)
#    Plnt      Material  Month  Total_cost     ADC  NDays  N3days  DOS  \
# 0  NL92  012204310004      5        0.00  738.40     31      92    8
# 1  NL92  012204310004      7      738.40    0.00     31      92    0
# 2  NL92  032210700233      3      199.68  580.32     31      91    6
# 3  NL92  032210700233      4      193.44  555.36     30      92    6
# 4  NL92  032210700233      5      199.68  542.88     31      92    6
#
#   Demand_flag                      Material Description Mat_Type  MRPpr  \
# 0              OMSNOERINGSBAND 16X0,5 (pallet a 700 kg)     HAWA  PMC1
# 1           X  OMSNOERINGSBAND 16X0,5 (pallet a 700 kg)     HAWA  PMC1
# 2              WIRE BRAID 14AWG CU/SN                       HAWA  BHWA
# 3              WIRE BRAID 14AWG CU/SN                       HAWA  BHWA
# 4              WIRE BRAID 14AWG CU/SN                       HAWA  BHWA
#
#    ProcType
# 0  F
# 1  F
# 2  F
# 3  F
# 4  F

# %%
## Save file
path = r"C:\Users\\DOS\DOS_calc.xlsx"
writer = pd.ExcelWriter(path, engine='xlsxwriter')
inventory_pm.to_excel(writer, sheet_name='Sheet1')
writer.save()
writer.close()
